# %%
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
import numpy as np
from python_file.w2v_utils import *
import pandas as pd
import collections

# %%
words, word_to_vec_map = read_glove_vecs('DATASET/W2V_150.txt')

# %% [markdown]
# # 1. Cosine similarity

# %%
def cosine_similarity(u, v):
    distance = 0.0

    # Compute the dot product between u and v (≈1 line)
    dot = np.dot(u,v)
    # Compute the L2 norm of u (≈1 line)
    norm_u = np.sqrt(np.sum(u * u))
    
    # Compute the L2 norm of v (≈1 line)
    norm_v = np.sqrt(np.sum(v * v))
    # Compute the cosine similarity defined by formula (1) (≈1 line)
    cosine_similarity = dot / (norm_u * norm_v)
    
    return cosine_similarity

# %%
file='DATASET/Visim-400.txt'
data_split = pd.read_csv(file, sep=" ")

# %%
words1 = []
words2 = []
for i in data_split['Word1\tWord2\tPOS\tSim1\tSim2\tSTD']:
    chunks = i.split('\t')
    words1.append(chunks[0])
    words2.append(chunks[1])

# %%
sims = []
for i_w in range(len(words1)):
    try:
        s_w1 = word_to_vec_map[words1[i_w]]
        s_w2 = word_to_vec_map[words2[i_w]]
        sim = cosine_similarity(s_w1, s_w2)
        print(words1[i_w],words2[i_w])
        print(sim)
        sims.append(sim)
    except KeyError:
        pass
# Out:
# biến ngập
# -0.004912339469670027
# nhà_thi_đấu nhà
# 0.08252318329211765
# động tĩnh
# 0.2770859598682774
# khuyết ưu
# 0.1767986283562671
# thủ_pháp biện_pháp
# 0.40236612919430603
# kết_duyên thành_hôn
# 0.4630084020140722
# cấp_tiến bảo_thủ
# 0.25694700889961236
# nước_lớn nguy_hiểm
# 0.18519202240211619
# hoa nhị
# 0.2230696045254854
# bất_lợi thuận_lợi
# 0.5348913029963392
# phân_ly sum_họp
# 0.07770108930396218
# diễu_hành tuần_hành
# 0.6438835401838533
# cao_trào thoái_trào
# 0.36103255277281715
# thịnh suy
# 0.059602370849219266
# con_voi ngà
# 0.23895503536998694
# cá_chuối cá_quả
# 0.16647413914742723
# đổ_bê_tông biếu_xén
# -0.1728400720961947
# con_đẻ con_ruột
# 0.6417888034717878
# uỷ_nhiệm phân_công
# 0.2875352779105757
# bay_lượn chuyển_động
# 0.3881971694440945
# khêu_gợi khơi_gợi
# 0.2559647287960097
# thăng_bằng cân_bằng
# 0.48043194238556186
# chọn_lựa tuyển_chọn
# 0.47242629887420834
# có_ích hữu_ích
# 0.662409385234064
# cứng_rắn nhỏ_nhắn
# 0.22523314998168
# lỗ_đen hố_đen
# 0.7340683342360697
# vùi đóng
# -0.013609544519483876
# tính_tình tính_khí
# 0.6878254420258124
# mục_sư giáo_sĩ
# 0.5964044436335486
# cộng_đồng dân_tộc
# 0.3754441422124707
# rớ sờ
# 0.38561358220504477
# trả_đũa đền_đáp
# 0.2330564641710549
# tay_cầm phân_đạm
# -0.030257136838635346
# liên_hệ nguỵ_trang
# 0.09239815053322079
# mới_tinh mới_toanh
# 0.48129019497587294
# cột_trụ bệ
# 0.4430288482597333
# họp_mặt tiệc
# 0.4276402056214263
# lộn_xộn gọn_gàng
# 0.34353721462857584
# chủ_động thụ_động
# 0.4777536040433243
# vali tay_cầm
# 0.16598255399110176
# ghen_tị ghen_ghét
# 0.3518800216281461
# ngôn_ngữ_học khoa_học
# 0.5372508509460164
# thu_gom tiếp_sức
# 0.17018185671127567
# quy_trình sáng_tác
# -0.09567834469126148
# thành_thị thị_thành
# 0.4058112852321535
# nhảy_nhót nhích
# 0.17700723858902043
# ly_tâm hướng_tâm
# 0.09295287557078617
# cống đường_ống
# 0.6561799539297557
# còm nhỏ_nhoi
# 0.15914793635264574
# bánh_răng răng
# 0.25739986258329367
# nao_núng kiên_định
# 0.2518184385854666
# bằng_hữu bầu_bạn
# 0.31387288886355963
# thân lưng
# 0.3079313269934209
# bút_chì lô
# 0.1415034613885759
# cổng ổ_khoá
# 0.3536777035092057
# dị_bản đĩa_bay
# 0.16630008250549988
# truy_cập thâm_nhập
# 0.49028561544494853
# âm nguy_hiểm
# 0.0902421933016787
# thăng_trầm khô_kiệt
# -0.009955192323517745
# thay_thế biến_đổi
# 0.18305778374734577
# ban_công lan_can
# 0.550133792871171
# dưới trên
# 0.21009877021166765
# kháng_cự phản_đối
# 0.05442648829061241
# vế vai_vế
# 0.19459174867201628
# vắng_lặng ồn_ào
# 0.553081938846813
# xót_thương đau_lòng
# 0.5396216352705175
# găng_tay quần_áo
# 0.4447774501118989
# sinh_vật_cảnh đồng_dao
# 0.1825286954575552
# lặn mọc
# 0.1884327286416303
# bồ_bịch nhân_tình
# 0.43056757732347745
# bằng_chứng chứng_cứ
# 0.728347957294409
# hạ_màn mở_màn
# 0.48128296649134483
# ca_tụng đoàn_kết
# 0.06165375134763974
# ngày đêm
# 0.5018292655269101
# lan_can rào
# 0.4971949287888648
# trở_lại đảo_ngược
# 0.26405524603416236
# nhạc_nhẹ tiểu_học
# -0.008235419222734665
# tự_do đức_tính
# 0.0016070145754620896
# hợp_nhất liên_kết
# 0.3381737506042728
# hoàng_tộc hoàng_gia
# 0.43346360554125285
# đầu_mối chỗ
# 0.16435135139844612
# tinh_luyện hoá_lỏng
# 0.3489107092225542
# bí_hiểm bí_mật
# 0.2876447889689539
# chung_tình phụ_bạc
# 0.39929497278315335
# bàn_cãi cân_nhắc
# 0.27706866745878245
# nhảy_cao ném_đĩa
# 0.47279604614419485
# tiếng_chuông âm_thanh
# 0.3806990925318217
# tha_thẩn thơ_thẩn
# 0.6520561739956902
# thuyền bánh_lái
# 0.39575242059890187
# nấp hiện
# 0.037029307474394146
# cất giấu
# 0.42559370637688393
# âm gốc
# 0.3002582475972697
# đặt thả_lỏng
# 0.11788818684113592
# chỉnh_hình tiểu_học
# 0.11930273869880285
# tẩy cạn
# 0.14183917722562253
# cây_trồng đĩa_bay
# 0.10001389172491254
# chỉnh_hình luồng
# -0.17340856215402964
# màng_tế_bào bảng_tổng_sắp
# -0.019664365856755836
# ngót_nghét xấp_xỉ
# 0.43308509164042486
# biến_động cố_định
# 0.23889655843263058
# khuyết_điểm ưu_điểm
# 0.39247415819755765
# nhạo_báng khiếm_nhã
# 0.47919043969216724
# hại lợi
# 0.2310026808217749
# bướu_cổ bệnh_tật
# 0.3949983289878127
# cây_thuốc cây_hoa_màu
# 0.3649579850276788
# tinh_lọc tinh_chế
# 0.5270150819554982
# bức_bối nguỵ_trang
# -0.04568560756811621
# thân_thể đầu
# -0.04944032913153986
# quỷ_quyệt xảo_quyệt
# 0.6348067524315942
# hoang_phí hà_tiện
# 0.5036435709308655
# cóp_nhặt để_dành
# 0.15002384579859185
# may rủi
# 0.07522659536547087
# tum chân_vịt
# 0.18165490346597904
# nhạo vèo
# 0.15451682858848512
# ngoại_lệ thường_lệ
# -0.03716774487133833
# phong_độ phong_thái
# 0.37012652970055804
# biết_ơn vô_ơn
# 0.2860110005075182
# buồn_bã nối_tiếp
# 0.09990871301551098
# quay chuyển_hướng
# 0.2961981499528089
# tập_dượt tập_luyện
# 0.4343145027357159
# oxy_hoá đổi_thay
# 0.11986410627414433
# trà bụi
# 0.22222659830449643
# phỏng mảnh
# 0.08176410293427971
# phòng_ngủ công_trình_phụ
# 0.28153874768024295
# hình_hoạ cung_bậc
# 0.1680256252911489
# hoạ phúc
# 0.11699808527980937
# nửa_mùa đồng_điệu
# -0.011829051147234789
# thịnh_hành hữu_tình
# 0.07773202880372383
# lời_lãi thua_lỗ
# 0.26650776943672877
# con_đường vỉa_hè
# 0.31174060578667145
# chính_nghĩa phi_nghĩa
# 0.5570493833559035
# trần_gian cõi_âm
# 0.34624409834103914
# vượng suy
# 0.008037526967852
# ấp_úng nói
# 0.21051430924976455
# thất_bại thành_công
# 0.4664567657052929
# ái_mộ hâm_mộ
# 0.4691648359613326
# nỗi_đau tai_hoạ
# 0.4903041567774523
# định_kỳ bất_thường
# 0.1438635231004214
# trước sau
# 0.5766044993249188
# đánh_bóng làm_đẹp
# 0.3821435174904365
# đoán quan_sát
# 0.32032802076548217
# đồ_dùng đồ_vật
# 0.574949227169155
# giải_tán tập_hợp
# 0.19389669564397183
# nhóm liên_kết
# 0.2416479539708365
# đầu_tiên cuối_cùng
# 0.5106627798317873
# quyển bìa
# 0.20940313081938844
# vượt_tuyến hằn_học
# -0.029710370501402867
# chiến_bại thắng_lợi
# 0.2837016049614862
# đỡ_đần bình_luận
# 0.017015264264734476
# hạ tăng
# 0.35986945925270425
# bội_bạc chung_thuỷ
# 0.33978852097293394
# nhà_máy dây_chuyền
# 0.35946235162793316
# tàu_hoả xe_điện_ngầm
# 0.4219105066378002
# thuở thủa
# 0.8614688965162297
# tranh trông_nom
# -0.033363034446847815
# xuôi ngược
# 0.3147970114480479
# biên_nhận móc
# 0.0038128645074773813
# thi_hành bắt
# 0.05875819222896622
# cự_tuyệt bãi_bỏ
# 0.3968391917193708
# hiện_trạng tình_cảnh
# 0.19672622271313028
# vượt_tuyến dứt_điểm
# 0.25933155773078465
# bằng văn_bằng
# 0.05538533879963634
# tĩnh_dưỡng lộn_xộn
# -0.021294972294592204
# nhốt thả
# 0.39828525430318856
# nội_tiết huyệt
# 0.18902841445299545
# phụ_bản truyện_tranh
# 0.34742932256996945
# phong_thư địa_chỉ
# 0.24974902912087055
# thời_bình thời_chiến
# 0.6089198433181582
# áo_quan quan_tài
# 0.6755826366795623
# trẩy_hội ví
# 0.053140554812611096
# cũ_kỹ mới_mẻ
# 0.32329093548038473
# sân_vận_động khán_đài
# 0.5706996461650229
# được mất
# -0.005103764065359726
# hiểu tiên_lượng
# 0.2526270231473788
# quét_dọn loại_bỏ
# 0.045425622535701975
# bay_hơi bay
# 0.1485309587805349
# dễ_dàng khó_khăn
# 0.42687936528822557
# gạ gạ_gẫm
# 0.6700650441380147
# nhậm_chức nhiệm_chức
# 0.3141633263083571
# hổ_thẹn bắt_buộc
# 0.2882365439992504
# dấu_hiệu đặc_trưng
# 0.1247499236460121
# người_dân tộc_người
# 0.3452384366954807
# bật_lửa giảm_xóc
# 0.1767910368689936
# sinh_vật_cảnh không_trung
# 0.07106153794008307
# chần_chờ dứt_khoát
# -0.08150806029953676
# tư_thế phong_thái
# 0.3356669673410032
# máy_vi_tính phím
# 0.23320122920705516
# sụp_đổ kìm_nén
# 0.22137551879886286
# mắc_kẹt cầm_giữ
# 0.47463479965705163
# hình_hoạ khí_quyển
# 0.09329309110204231
# thuộc_địa kiều_dân
# 0.32038918929696997
# nhà_hát sân_khấu
# 0.4406483602432743
# thìa muỗng
# 0.8422977453212419
# tỏ biểu_lộ
# 0.4975748131956014
# chiến_tranh trận_chiến
# 0.41155810481633043
# cộc va
# 0.03402576743432389
# tính_sổ giám_đốc_thẩm
# 0.0309784792464729
# hơn thua
# 0.08605219900956888
# cựu_binh tân_binh
# 0.45581411434867436
# tính_sổ nuôi_dưỡng
# 0.07438552352594878
# hâm_nóng cải_biến
# 0.39097386200228257
# bón tẩm
# 0.22687194401456268
# thảm thê_thảm
# 0.21824307524141237
# lắp_đặt nhồi_nhét
# 0.0891352226481322
# tạo_hoá tạo_vật
# 0.29902520106436087
# hen cúm
# 0.33930907846790215
# mệt_mỏi mỏi_mệt
# 0.7741543992805755
# tắc_nghẽn thông_suốt
# 0.36459718913377687
# trọng coi_trọng
# 0.382431498432439
# đẽo bắt
# 0.06499285201502493
# hú ca
# 0.14642503430199724
# danh_sách mục
# 0.2519029793272171
# chuyển_nhượng phát_mại
# 0.1825770346821192
# vòng_tay trang_sức
# 0.1120260962005443
# đổ_bê_tông chăm_sóc
# 0.055979056308361044
# kín phát
# 0.018338220644070383
# người_tình chiến_sĩ
# 0.10625734688523504
# cuối đầu
# 0.6423954310858537
# cần_tây đậu_bắp
# 0.5502537205294665
# định_kì bất_thường
# 0.1585625668543303
# thiện_chí ác_ý
# 0.30474690142029737
# biên_cương biên_giới
# 0.355631243190808
# sông cửa_sông
# 0.6408591579368887
# tím bẹp
# 0.1081272416585234
# năm_âm_lịch tháng_âm_lịch
# 0.5719292130062954
# đỡ_đần suy_xét
# 0.1546896504490783
# bầm mệ
# 0.0414519368540957
# dáng tản_bộ
# 0.10091694820831952
# sinh_vật tế_bào
# 0.4987182279416986
# nhau rau
# 0.1163071135065608
# đồng_tình phản_đối
# 0.29063934887732507
# thanh dụng_cụ
# 0.14819665087209494
# điệu háo
# 0.10802345785899911
# 0.19001757095205227
# đâm_sầm phóng
# 0.32445784354190865
# bò đi
# -0.0008110941303699206
# nội_tiết luồng
# 0.005273336871372637
# dị_ứng lương_tri
# -0.011613802522149734
# vặn vặn_vẹo
# 0.33296607923348137
# lùng_bùng vắng_ngắt
# 0.17995018188629502
# chê khen
# 0.2581145892891667
# tượng_đài bảng_tổng_sắp
# 0.06362501672097448
# người_yêu tình_nhân
# 0.40740558634368057
# thiện_cảm ác_cảm
# 0.5909680719076432
# trau_chuốt phát_triển
# 0.13353498403895525
# gươm lưỡi
# 0.2521803255020299
# bánh_xe vành
# 0.46215484555201247
# tượng_đài phân_bón
# -0.08608104825305282
# nạc búi
# 0.14359299098434866
# khung_thành cầu_môn
# 0.9057290306863822
# kĩ sơ_sài
# 0.3576096489593773
# buồn vui
# 0.6325065472381485
# nhược_điểm ưu_điểm
# 0.6970440205524105
# quan_hệ trạng_thái
# 0.17921900133157104
# đong_đưa vung_vẩy
# 0.37250375118444895
# bừa_bãi gọn_ghẽ
# 0.16428640446301584
# nhà_thơ thi_nhân
# 0.6541988461158453
# máy_tính vi_xử_lý
# 0.4372469749456561
# né_tránh hích
# 0.08713397403587106
# địch ta
# 0.3410369530265619
# lưu_thông ách_tắc
# 0.29461659219600633
# thứ_yếu rộng_rãi
# 0.03854739022579874
# đặt_chân thay
# 0.20622362094102545
# dì_ghẻ phụ_huynh
# 0.24376703521286547
# rỗi rỗi_rãi
# 0.5151665388049849
# tái_phát nhiễm_khuẩn
# 0.40951605781358075
# mầm rau_quả
# 0.19994660282373253
# hạn_hán lụt_lội
# 0.6742159346587001
# lưỡng_lự dứt_khoát
# 0.23061574870977233
# tung cấp_phát
# 0.1835720811240651
# giầu khó
# 0.13696782538735877
# làm_đẹp cải_tạo
# 0.18459015221021585
# ban_mai sớm_mai
# 0.47671181765654586
# quỳ ví
# 0.056713830134879024
# bại_lộ lộ
# 0.470767001732449
# tính_cách phẩm_chất
# 0.4944465344278003
# triều_đại cổ_đại
# 0.27437585638489387
# lình_xình nặng_tình
# 0.17049420746310423
# người_làm người_bị_hại
# 0.1350079186615406
# chần_chừ lảo_đảo
# 0.11293908545899892
# khử_trùng sát_trùng
# 0.7052270180481737

# %% [markdown]
# # 2. K-nearest words

# %%
def k_nearest_words(word, all_words):
    all_sims = []
    top_k = dict()
    try:
        word_vector = word_to_vec_map[word]
        for idx in all_words:
            try:
                idx_vector = word_to_vec_map[idx]
                similarity = cosine_similarity(word_vector, idx_vector)
                top_k.update({idx:similarity})
            except KeyError:
                pass
        return (word, sorted(top_k.items(), key=lambda x: x[1], reverse=True)[:10]) 
    except KeyError:
        pass

# %%
for e_w in words1:
    print(k_nearest_words(e_w, words2),'\n')
# Out:
# ('biến', [('loại_bỏ', 0.39982202546609236), ('trừ_khử', 0.3577853111161979), ('phát_triển', 0.35468234283556915), ('cải_biến', 0.3499645711349526), ('thuần_hoá', 0.32730778322543275), ('tập_hợp', 0.2970481096627491), ('đảo_ngược', 0.29586987173526696), ('biến_đổi', 0.2715603489232827), ('chuyển_hướng', 0.25468541368467756), ('khơi_gợi', 0.2513066830497953)])
# ('người_làm', [('người_dân', 0.21750448925695676), ('ác_ý', 0.20487951787067754), ('phân_công', 0.19561381223498922), ('người_lớn', 0.19397857518128786), ('hữu_ích', 0.1870886955623775), ('khó_khăn', 0.18641197025040052), ('làm_đẹp', 0.1860869130563754), ('rỗi_rãi', 0.1773963879160193), ('tuyển_chọn', 0.17227822871092888), ('lương_tri', 0.1697093013727795)])
#
# None
#
# ('chần_chừ', [('ngúng_nguẩy', 0.2996378316632548), ('suy_xét', 0.28581019185671813), ('thụ_động', 0.27870933537134807), ('mỏi_mệt', 0.27451389334882087), ('tĩnh_dưỡng', 0.26496739699191524), ('kìm_nén', 0.25999022441860414), ('chệch_choạc', 0.2533391435425608), ('cân_nhắc', 0.24978787104102693), ('nhích', 0.24519323349274258), ('kẹt', 0.23860000333775497)])
#
# ('khử_trùng', [('sát_trùng', 0.7052270180481737), ('nhiễm_khuẩn', 0.3389148611134213), ('cấp_phát', 0.32345957088118416), ('tẩm', 0.3226511801974703), ('chăm_sóc', 0.3171940811316714), ('cúm', 0.2911988705645205), ('dụng_cụ', 0.27673257494666254), ('rau_quả', 0.26698116941785005), ('tiên_tiến', 0.25283381812214945), ('cải_tạo', 0.25144828355320203)])

# %% [markdown]
# # 3. Synonym-antonym classification

# %%
ant = open('DATASET/Antonym_vietnamese.txt', 'r').read().strip('\n').split('\n')
syn = open('DATASET/Synonym_vietnamese.txt', 'r').read().strip('\n').split('\n')

# %%
corpus = []
for pair in ant:
    corpus.extend(pair.split(' '))
for pair in syn:
    corpus.extend(pair.split(' '))
corpus = list(set(corpus))
corpus = {word: i for (i, word) in enumerate(corpus)}
corpus['UNK'] = len(corpus)
X = []
y = []
print(len(corpus))
# Out:
# 14150

# %%
corpus
# Out:
# {'': 0,
#  'cởi': 1,
#  'sửa_chữa': 2,
#  'hồng_hoa': 3,
#  'thoả_thuê': 4,
#  'ốm_nhách': 5,
#  'ăn_mặc': 6,
#  'trái_phiếu': 7,
#  'cật_lực': 8,
#  'thòi': 9,
#  'chia_cắt': 10,
#  'mó_máy': 11,
#  'cho_qua': 12,
#  'gọi': 13,
#  'phá_lưới': 14,
#  'chợn': 15,
#  'cùn_đời': 16,
#  'nhớ_mong': 17,
#  'đen_sì': 18,
#  'cộm': 19,
#  'sột_soạt': 20,
#  'kí_sự': 21,
#  'phát_đơn': 22,
#  'nổi_tam_bành': 23,
#  'bảo_thủ': 24,
#  'để_ý': 25,
#  'ánh_ỏi': 26,
#  'khư_khư': 27,
#  'điêu_trá': 28,
#  'vùng_vẫy': 29,
#  'tam_giác': 30,
#  'lầm_rầm': 31,
#  'mao_mạch': 32,
#  'am_hiểu': 33,
#  'nạnh': 34,
#  'đan': 35,
#  'vang_dậy': 36,
#  'tức_thì': 37,
#  'thẳng_tuột': 38,
#  'chiến_lược_quân_sự': 39,
#  'chứa_chấp': 40,
#  'ương_ngạnh': 41,
#  'dành': 42,
#  'tàu_bè': 43,
#  'đảo': 44,
#  'thăng_thiên': 45,
#  'thước_ta': 46,
#  'chả_hạn': 47,
#  'dăn_dúm': 48,
#  'chi_phí': 49,
#  'chăm_chú': 50,
#  'bõ_bèn': 51,
#  'luật_bài_trung': 52,
#  'gợn': 53,
#  'chấm_hỏi': 54,
#  'lạnh_giá': 55,
#  'chí_thân': 56,
#  'mất_công': 57,
#  'tiếng_nói': 58,
#  'phơi': 59,
#  'tạp_phẩm': 60,
#  'do_dự': 61,
#  'hanh_hao': 62,
#  'báo_thù': 63,
#  'bóc_trần': 64,
#  'nghề_nghiệp': 65,
#  'bộng_ong': 66,
#  'nghển': 67,
#  'nón_quai_thao': 68,
#  'xẩm': 69,
#  'nơm_nớp': 70,
#  'phải': 71,
#  'máy_bay_lên_thẳng': 72,
#  'lợn_ỉ': 73,
#  'anh_linh': 74,
#  'bánh_mật': 75,
#  'quờ_quạng': 76,
#  'dở_dói': 77,
#  'cận_kim': 78,
#  'tấm_tắc': 79,
#  'đại_tiện': 80,
#  'tin_tặc': 81,
#  'quýnh_quáng': 82,
#  'thoả_mãn': 83,
#  'nhẩy_sào': 84,
#  'nhợ': 85,
#  'ngời_ngời': 86,
#  'suy_lý_trực_tiếp': 87,
#  'phương_ngữ': 88,
#  'cắm_đầu': 89,
#  'càn_bậy': 90,
#  'chỏng_vó': 91,
#  'sắm_sửa': 92,
#  'vật_lý_hiện_đại': 93,
#  'thái_bình': 94,
#  'hôn_thê': 95,
#  'sừn_sựt': 96,
#  'kim_đan': 97,
#  'giả_bộ': 98,
#  'cám_hấp': 99,
#  'cương_vực': 100,
#  'lêu_lổng': 101,
#  'nhảy_cóc': 102,
#  'tán_gẫu': 103,
#  'trên_cơ': 104,
#  'quá_quắt': 105,
#  'đám_tang': 106,
#  'tạm': 107,
#  'bẳn_gắt': 108,
#  'chấm_than': 109,
#  'ghê_tởm': 110,
#  'bất_tiện': 111,
#  'điệu_này': 112,
#  'lưỡng_cư': 113,
#  'trường_đoản_cú': 114,
#  'lạnh_lẽo': 115,
#  'nhiệm_chức': 116,
#  'cá_thiều': 117,
#  'sinh_lý': 118,
#  'chuyển_biến': 119,
#  'chủ_nghĩa_kinh_viện': 120,
#  'day': 121,
#  'dancing': 122,
#  'giật_thột': 123,
#  'vội_vàng': 124,
#  'tin_tưởng': 125,
#  'thời_kỳ': 126,
#  'đâm_họng': 127,
#  'đinh_rệp': 128,
#  'hoắm': 129,
#  'muối_bỏ_bể': 130,
#  'ác_độc': 131,
#  'nấu_nướng': 132,
#  'sớm': 133,
#  'tỉnh_lỵ': 134,
#  'quân_lính': 135,
#  'lờ_mờ': 136,
#  'tên_lửa_đường_đạn': 137,
#  'thù_hằn': 138,
#  'niễng': 139,
#  'nhẩy_dây': 140,
#  'mong_ước': 141,
#  'tỉ_ti': 142,
#  'hẵng': 143,
#  'muôn_ngàn': 144,
#  'cấp_tốc': 145,
#  'bội_thu': 146,
#  'nhẹ_nhàng': 147,
#  'quả_phụ': 148,
#  'tít': 149,
#  'vu_vạ': 150,
#  'xuất_biên': 151,
#  'hồng': 152,
#  'canh': 153,
#  'quảng_cáo': 154,
#  'nhổm': 155,
#  'ơ_hay': 156,
#  'chân_tình': 157,
#  'họp': 158,
#  'đảng_kỳ': 159,
#  'mân_mê': 160,
#  'ngộ': 161,
#  'sài_giật': 162,
#  'nói_ngọt': 163,
#  'lông_mày': 164,
#  'trinh_tiết': 165,
#  'bế_bồng': 166,
#  'nháy_đúp': 167,
#  'cửa_biển': 168,
#  'hải_li': 169,
#  'quãng': 170,
#  'thẩn_thơ': 171,
#  'đần': 172,
#  'danh_dự': 173,
#  'cố': 174,
#  'thiển_nghĩ': 175,
#  'cãi_lẫy': 176,
#  'hoa_tigôn': 177,
#  'khốn_cùng': 178,
#  'liệu_cái_thần_hồn': 179,
#  'tưng_hửng': 180,
#  'khói_hương': 181,
#  'ngửa_nghiêng': 182,
#  'tan_vỡ': 183,
#  'da_gai': 184,
#  'đành_rằng': 185,
#  'phôi_pha': 186,
#  'tất': 187,
#  'thề_thốt': 188,
#  'dở_người': 189,
#  'trứ_tác': 190,
#  'vì': 191,
#  'khuyết_tật': 192,
#  'biệt_lập': 193,
#  'mong_chờ': 194,
#  'nhì_nhằng': 195,
#  'thực_chất': 196,
#  'rèn_luyện': 197,
#  'ép': 198,
#  'báo_hỉ': 199,
#  'nấu_ăn': 200,
#  'phụ_tình': 201,
#  'li_tâm': 202,
#  'dáng_vẻ': 203,
#  'muôn_vàn': 204,
#  'chứng_cứ': 205,
#  'đối_nghịch': 206,
#  'tẩm_liệm': 207,
#  'tuyển_lựa': 208,
#  'tròn': 209,
#  'ỉ_eo': 210,
#  'trời_ơi_đất_hỡi': 211,
#  'dang': 212,
#  'dấu_gạch_nối': 213,
#  'rỉa_rói': 214,
#  'đắc_cử': 215,
#  'bởi_thế': 216,
#  'du_nhập': 217,
#  'khoa_ngoại': 218,
#  'ngấm_ngầm': 219,
#  'tuỳ_tung': 220,
#  'vang_lừng': 221,
#  'bình_phẩm': 222,
#  'bén_mảng': 223,
#  'gắn': 224,
#  'thục': 225,
#  'buji': 226,
#  'nín': 227,
#  'rũ_rợi': 228,
#  'lạt_lẽo': 229,
#  'quản_lý': 230,
#  'lang_bạt_kì_hồ': 231,
#  'gọn_nhẹ': 232,
#  'nanh_vuốt': 233,
#  'phi_lí': 234,
#  'chính_qui': 235,
#  'la_hét': 236,
#  'ROM': 237,
#  'an_lành': 238,
#  'khôn_cùng': 239,
#  'chóng_vánh': 240,
#  'đĩ_điếm': 241,
#  'phao_đồn': 242,
#  'thư_lưu_ký': 243,
#  'phi_pháp': 244,
#  'chằm_chặp': 245,
#  'gôn': 246,
#  'bức': 247,
#  'lỏng_lẻo': 248,
#  'dì_ghẻ': 249,
#  'tươm': 250,
#  'om_sòm': 251,
#  'chép': 252,
#  'chôm': 253,
#  'trắng_trong': 254,
#  'tỷ': 255,
#  'trú_ngụ': 256,
#  'tàn_sát': 257,
#  'mang_bành': 258,
#  'bánh_mướt': 259,
#  'sải': 260,
#  'ngất_ngưởng': 261,
#  'trắc_bách_diệp': 262,
#  'xanh_xao': 263,
#  'ác_tâm': 264,
#  'nòi': 265,
#  'vọc_vạch': 266,
#  'rạng_rỡ': 267,
#  'mưu_kế': 268,
#  'vòng_vèo': 269,
#  'nậy': 270,
#  'đàn_xếp': 271,
#  'cảnh_vừa': 272,
#  'học_vấn': 273,
#  'kết_giao': 274,
#  'cối_cần': 275,
#  'nguyên_lí': 276,
#  'chăm_bẳm': 277,
#  'suýt_nữa': 278,
#  'bọ_mát': 279,
#  'ăn_phải_đũa': 280,
#  'áo_ấm': 281,
#  'y_lý': 282,
#  'đoàn_tụ': 283,
#  'đánh_tháo': 284,
#  'trừ_khử': 285,
#  'công_ty_mẹ': 286,
#  'vấn': 287,
#  'bìu_dái': 288,
#  'bít_cốt': 289,
#  'giao_hợp': 290,
#  'nhập_cảng': 291,
#  'khích': 292,
#  'dao_nề': 293,
#  'chăm_nom': 294,
#  'lạch_bạch': 295,
#  'lẳn': 296,
#  'trêu_ghẹo': 297,
#  'êm_ấm': 298,
#  'cầu_môn': 299,
#  'nhầu_nát': 300,
#  'gây_chuyện': 301,
#  'niêm_mạc': 302,
#  'tại_sao': 303,
#  'dìu_dắt': 304,
#  'cứng_rắn': 305,
#  'mở_mắt': 306,
#  'chập_choạng': 307,
#  'sao_Thuỷ': 308,
#  'thế_gian': 309,
#  'màu_mè': 310,
#  'rởn': 311,
#  'bê_tông_cốt_sắt': 312,
#  'không_dưng': 313,
#  'mách': 314,
#  'thước_tỷ_lệ': 315,
#  'oxygen': 316,
#  'tầy_trời': 317,
#  'hình_nhi_thượng': 318,
#  'vi_xử_lí': 319,
#  'đại_thắng': 320,
#  'giả_trá': 321,
#  'tiếng_là': 322,
#  'đồng_mưu': 323,
#  'nhảy_xổ': 324,
#  'tập_tõng': 325,
#  'quy_lát': 326,
#  'ngược_ngạo': 327,
#  'nguyên': 328,
#  'xoay_vần': 329,
#  'quyết_chí': 330,
#  'hình_như': 331,
#  'đổ_đồng': 332,
#  'hợp_pháp': 333,
#  'uốn_ván': 334,
#  'đông_nghẹt': 335,
#  'modem': 336,
#  'nảy_sinh': 337,
#  'thoả_đáng': 338,
#  'hoà_hợp': 339,
#  'giãn_nở': 340,
#  'phác_hoạ': 341,
#  'cổ_lai_hy': 342,
#  'bế_giảng': 343,
#  'bươm': 344,
#  'kín': 345,
#  'dùng_dắng': 346,
#  'vén': 347,
#  'ân_đức': 348,
#  'năng_khiếu': 349,
#  'mặt': 350,
#  'tang_vật': 351,
#  'dở_dang': 352,
#  'kẻ_thù': 353,
#  'đàng_hoàng': 354,
#  'đèn_điện_tử': 355,
#  'thành_danh': 356,
#  'tỉ_mỉ': 357,
#  'đi_đồng': 358,
#  'nhưng': 359,
#  'khẽ_khàng': 360,
#  'vật_chướng_ngại': 361,
#  'nhúng': 362,
#  'nhìn': 363,
#  'ngát': 364,
#  'nhầm_nhỡ': 365,
#  'nói_kháy': 366,
#  'nặng_kí': 367,
#  'băng_xăng': 368,
#  'vơ_váo': 369,
#  'chú_trọng': 370,
#  'chầu_văn': 371,
#  'cơ_lỡ': 372,
#  'trung_kiên': 373,
#  'xích_mích': 374,
#  'cố_định': 375,
#  'đám_xá': 376,
#  'quờ': 377,
#  'rắn': 378,
#  'hèn_hạ': 379,
#  'chệch': 380,
#  'toán_loạn': 381,
#  'lèo_khoèo': 382,
#  'cuốc_bộ': 383,
#  'luỗng': 384,
#  'thư_thả': 385,
#  'tỉnh_khô': 386,
#  'tung_toé': 387,
#  'mức_độ': 388,
#  'ăn_khách': 389,
#  'nhạc_điệu': 390,
#  'đi_tả': 391,
#  'quăng_quật': 392,
#  'bèo_hoa_dâu': 393,
#  'xử_lý': 394,
#  'đạm_bạc': 395,
#  'đú_đa_đú_đởn': 396,
#  'mặc_thây': 397,
#  'thang': 398,
#  'hào_chiến_đấu': 399,
#  'nhảy_dây': 400,
#  'đinh_vít': 401,
#  'cộng_sự': 402,
#  'cánh_vảy': 403,
#  'quy_y': 404,
#  'ca_ri': 405,
#  'cà_kê': 406,
#  'tha_thẩn': 407,
#  'đôi': 408,
#  'vật_lí': 409,
#  'ngụp': 410,
#  'hung_bạo': 411,
#  'bê_tha': 412,
#  'hủ_lậu': 413,
#  'đề_xướng': 414,
#  'tai_ngược': 415,
#  'vồn_vã': 416,
#  'rùng_rợn': 417,
#  'sắm_nắm': 418,
#  'cha_mẹ': 419,
#  'điện_thoại': 420,
#  'bủa_vây': 421,
#  'tiêu_xài': 422,
#  'sợ': 423,
#  'hàm_súc': 424,
#  'nuốm': 425,
#  'bận_tâm': 426,
#  'điệp_viên': 427,
#  'bình_bịch': 428,
#  'ọc': 429,
#  'phỉnh': 430,
#  'xa_tít': 431,
#  'giầu': 432,
#  'khôn': 433,
#  'báu_vật': 434,
#  'bệnh_tật': 435,
#  'măm': 436,
#  'ô_tô_hòm': 437,
#  'ráp_nối': 438,
#  'sờm_sỡ': 439,
#  'khởi_thuỷ': 440,
#  'dúm_dó': 441,
#  'dã_man': 442,
#  'kĩ_lưỡng': 443,
#  'lỉnh': 444,
#  'bùa_chú': 445,
#  'giờ_hồn': 446,
#  'chan_chát': 447,
#  'phong_cầm': 448,
#  'phấp_phỏng': 449,
#  'điêu_ngoa': 450,
#  'quý_danh': 451,
#  'hí_húi': 452,
#  'pháo_đùng': 453,
#  'đàn_tỳ': 454,
#  'cũ': 455,
#  'tiêu_ma': 456,
#  'quyến_luyến': 457,
#  'kỷ': 458,
#  'điềm_nhiên': 459,
#  'đèn_bán_dẫn': 460,
#  'yên': 461,
#  'ngắn': 462,
#  'sáng': 463,
#  'giảng_giải': 464,
#  'đè_đầu_cưỡi_cổ': 465,
#  'điên_cuồng': 466,
#  'thều_thào': 467,
#  'bủn': 468,
#  'cha_nội': 469,
#  'hoa_cương': 470,
#  'mạng': 471,
#  'bồi_thường': 472,
#  'đẹp_giai': 473,
#  'vị': 474,
#  'rẽ_ròi': 475,
#  'nhẵn_thín': 476,
#  'diễn_đạt': 477,
#  'ruột_gan': 478,
#  'lì_xì': 479,
#  'phụ': 480,
#  'tục_danh': 481,
#  'giấy_nến': 482,
#  'rì_rầm': 483,
#  'kỷ_yếu': 484,
#  'bội_nghĩa': 485,
#  'hẹp': 486,
#  'phá_rào': 487,
#  'thiết_diện': 488,
#  'dục_tính': 489,
#  'đánh_vật': 490,
#  'giôn_giốt': 491,
#  'olympic': 492,
#  'vớ': 493,
#  'giải_nghĩa': 494,
#  'kiêu_ngạo': 495,
#  'đi': 496,
#  'lọt_lòng': 497,
#  'luận_chiến': 498,
#  'nhắng': 499,
#  'xỏ_xiên': 500,
#  'cần_yếu': 501,
#  'lác_đác': 502,
#  'tâng': 503,
#  'tham_số': 504,
#  'chiến_chinh': 505,
#  'nghèo_đói': 506,
#  'đại_số_học': 507,
#  'trợ_giúp': 508,
#  'mủ': 509,
#  'bồng_bềnh': 510,
#  'buồn_phiền': 511,
#  'quá_cố': 512,
#  'ti_thể': 513,
#  'bảo_nhỏ': 514,
#  'thư_điện_tử': 515,
#  'tổn_hao': 516,
#  'học_đòi': 517,
#  'nghề_đời': 518,
#  'phắt': 519,
#  'kiềm_toả': 520,
#  'ứng_xử': 521,
#  'chè_thuốc': 522,
#  'đồng_bạc': 523,
#  'giấy_chặm': 524,
#  'pháo_sáng': 525,
#  'chịu_nhiệt': 526,
#  'ly_gián': 527,
#  'đoàn_viên': 528,
#  'nguyên_tố_hoá_học': 529,
#  'bằng_vai': 530,
#  'hạ_tiện': 531,
#  'hấp_dẫn': 532,
#  'cõi_trần': 533,
#  'thuỷ_đậu': 534,
#  'cự_ly': 535,
#  'khoăm': 536,
#  'bớt': 537,
#  'cải_xoong': 538,
#  'ám_muội': 539,
#  'tai_phôn': 540,
#  'tuân_thủ': 541,
#  'giũa': 542,
#  'thứ_yếu': 543,
#  'khoa': 544,
#  'đầy_ải': 545,
#  'nhục_nhã': 546,
#  'tầu_bay': 547,
#  'vật_lộn': 548,
#  'đu': 549,
#  'xấp': 550,
#  'tương_ứng': 551,
#  'cày_ấp': 552,
#  'phân_phất': 553,
#  'chả_là': 554,
#  'tùm': 555,
#  'thối': 556,
#  'cất_quân': 557,
#  'kí_sinh': 558,
#  'hỉ_hả': 559,
#  'chiếp': 560,
#  'sục_sôi': 561,
#  'ngay_ngắn': 562,
#  'cỗ': 563,
#  'truy_hỏi': 564,
#  'sống_mái': 565,
#  'nhảy_sào': 566,
#  'kì_thị': 567,
#  'một_lòng': 568,
#  'công_nhân_quí_tộc': 569,
#  'lấp_ló': 570,
#  'nhàu_nát': 571,
#  'kiến_vàng': 572,
#  'hứa_hẹn': 573,
#  'khiếp_vía': 574,
#  'nát_nước': 575,
#  'niên_học': 576,
#  'biển_thủ': 577,
#  'tiền_phong': 578,
#  'hỡi_ôi': 579,
#  'suy_tị': 580,
#  'tiếc': 581,
#  'thướt_tha': 582,
#  'quần_đông_xuân': 583,
#  'nhỏ_con': 584,
#  'út_ít': 585,
#  'cam_lòng': 586,
#  'sẩm': 587,
#  'âm_hộ': 588,
#  'sức_mạnh': 589,
#  'đại_lượng_tỷ_lệ_nghịch': 590,
#  'nguôi': 591,
#  'ruộng_rẫy': 592,
#  'cuối': 593,
#  'thiệt': 594,
#  'tư_thục': 595,
#  'xịn': 596,
#  'đàn_nguyệt': 597,
#  'hải_lý': 598,
#  'thơm_phức': 599,
#  'dẫn_chất': 600,
#  'nhăng_nhít': 601,
#  'người_yêu': 602,
#  'pháp_lí': 603,
#  'sấm_kí': 604,
#  'rộc_rạc': 605,
#  'oi_bức': 606,
#  'đảng_tính': 607,
#  'kỷ_vật': 608,
#  'ơn_huệ': 609,
#  'vị_nể': 610,
#  'ma_tà': 611,
#  'sả': 612,
#  'ngơi': 613,
#  'thành_công': 614,
#  'mão': 615,
#  'xộc_xệch': 616,
#  'ơ': 617,
#  'hàm_hồ': 618,
#  'bươi': 619,
#  'ni': 620,
#  'cứa': 621,
#  'nhanh_chóng': 622,
#  'bạch': 623,
#  'đèn_huỳnh_quang': 624,
#  'nhức_nhói': 625,
#  'quân_dịch': 626,
#  'điều_động': 627,
#  'dát_gái': 628,
#  'mọi': 629,
#  'nói_riêng': 630,
#  'nguyên_nhân': 631,
#  'nghèo_khổ': 632,
#  'ngừng_nghỉ': 633,
#  'dễ_thường': 634,
#  'phe_cánh': 635,
#  'xăng_xái': 636,
#  'muôn_đời': 637,
#  'công_lao': 638,
#  'quá_cỡ': 639,
#  'ngóng_chờ': 640,
#  'hối_cải': 641,
#  'mảnh': 642,
#  'bệnh': 643,
#  'ông_già': 644,
#  'nhất_nhất': 645,
#  'tỷ_phú': 646,
#  'húng_hắng': 647,
#  'hiệu_đính': 648,
#  'loà_nhoà': 649,
#  'sớt': 650,
#  'lẻ': 651,
#  'qui_tắc': 652,
#  'cô_đỡ': 653,
#  'hải_sản': 654,
#  'con_tạo': 655,
#  'để_tâm': 656,
#  'đèn_dù': 657,
#  'dịp': 658,
#  'bất_thành_văn': 659,
#  'đường_sá': 660,
#  'khát_khao': 661,
#  'danh_giá': 662,
#  'chân_quì': 663,
#  'giở_giời': 664,
#  'bần_thần': 665,
#  'vẫn': 666,
#  'khuếch_khoác': 667,
#  'lý_do': 668,
#  'cực_kỳ': 669,
#  'loanh_quanh': 670,
#  'thích_ứng': 671,
#  'chả_giò': 672,
#  'cưỡi_cổ': 673,
#  'hóc_hiểm': 674,
#  'lần_thần': 675,
#  'hậu_tập': 676,
#  'kèn_bầu': 677,
#  'đánh_đùng': 678,
#  'nhanh_nhảu': 679,
#  'van_lạy': 680,
#  'mập_ú': 681,
#  'bửa': 682,
#  'dạ_tiệc': 683,
#  'tục_ngữ': 684,
#  'quơ': 685,
#  'tạm_biệt': 686,
#  'tình': 687,
#  'lả_lướt': 688,
#  'đằm_thắm': 689,
#  'núi_băng': 690,
#  'bắt_buộc': 691,
#  'trùng_trùng': 692,
#  'chúa_thượng': 693,
#  'trường_học': 694,
#  'xải': 695,
#  'dường': 696,
#  'siêu': 697,
#  'tiết_diện': 698,
#  'quy_củ': 699,
#  'bồ_bịch': 700,
#  'đối_mặt': 701,
#  'nhỉnh': 702,
#  'nỗi': 703,
#  'đề': 704,
#  'kiêu': 705,
#  'bệnh_bạch_cầu': 706,
#  'thớ': 707,
#  'thoái_lui': 708,
#  'lừ_khừ': 709,
#  'trái_tính': 710,
#  'ngày': 711,
#  'bày_vai': 712,
#  'bắt_đầu': 713,
#  'va_chạm': 714,
#  'oe_oe': 715,
#  'thực_tại': 716,
#  'bay_nhảy': 717,
#  'tai_ương': 718,
#  'đô_thị': 719,
#  'tông_tích': 720,
#  'tạo_vật': 721,
#  'sụ': 722,
#  'ngày_mai': 723,
#  'nằm_mơ': 724,
#  'sâu_cay': 725,
#  'magma': 726,
#  'ngàn_thu': 727,
#  'cấn': 728,
#  'phẫn_khích': 729,
#  'ghi_tạc': 730,
#  'nội_khoa': 731,
#  'phân_tích': 732,
#  'trêu_chọc': 733,
#  'thừa_mứa': 734,
#  'lúc': 735,
#  'ưa': 736,
#  'cây_cổ_thụ': 737,
#  'hầm': 738,
#  'thảo_dược': 739,
#  'hận_cừu': 740,
#  'opera': 741,
#  'liên_hệ': 742,
#  'thẹo': 743,
#  'lay_chuyển': 744,
#  'cà_khổ': 745,
#  'quá_đỗi': 746,
#  'díu': 747,
#  'đưỡn': 748,
#  'quân_kỳ': 749,
#  'tang_chủ': 750,
#  'trổ': 751,
#  'lẩm_bẩm': 752,
#  'ngạch_bậc': 753,
#  'hạ_nhục': 754,
#  'phanh_phui': 755,
#  'tai_nghe': 756,
#  'bù_xù': 757,
#  'bố_mẹ': 758,
#  'lẫn_lộn': 759,
#  'xao_xác': 760,
#  'bỏ_cha': 761,
#  'tịt': 762,
#  'xẹp_lép': 763,
#  'gió_mùa_đông-bắc': 764,
#  'chết_đuối': 765,
#  'lấm_lét': 766,
#  'làm_phản': 767,
#  'tự_trọng': 768,
#  'toả': 769,
#  'mạo': 770,
#  'phịch': 771,
#  'nhà_chứa': 772,
#  'chỏng_chơ': 773,
#  'liệu_chừng': 774,
#  'biện': 775,
#  'Hoả_Tinh': 776,
#  'kiên_nghị': 777,
#  'bền_chí': 778,
#  'giương': 779,
#  'bỏ_xác': 780,
#  'lảu_bảu': 781,
#  'bàng_quan': 782,
#  'biệt_hiệu': 783,
#  'bỏ_bố': 784,
#  'tày_đình': 785,
#  'cộng': 786,
#  'vẽ': 787,
#  'lao': 788,
#  'hữu_hảo': 789,
#  'tuần_tra': 790,
#  'ăn_báo_cô': 791,
#  'cô_nhi_viện': 792,
#  'bình_đẳng': 793,
#  'còm_nhỏm': 794,
#  'phản_nghịch': 795,
#  'ghi_âm': 796,
#  'vần_vũ': 797,
#  'kí_hiệu_học': 798,
#  'trở': 799,
#  'thứ_hạng': 800,
#  'cha_ông': 801,
#  'kí_chủ': 802,
#  'cá_rựa': 803,
#  'giò_lụa': 804,
#  'bôi_đen': 805,
#  'van': 806,
#  'coi_sóc': 807,
#  'nguồn_gốc': 808,
#  'hồi_kí': 809,
#  'thụt': 810,
#  'lưng_vốn': 811,
#  'nghen': 812,
#  'rắn_đầu_rắn_mặt': 813,
#  'buồn': 814,
#  'sơ_đồ': 815,
#  'curoa': 816,
#  'biếc': 817,
#  'dùng': 818,
#  'nhoài': 819,
#  'lầm_lỗi': 820,
#  'vui_tươi': 821,
#  'lặng_yên': 822,
#  'giảng_nghĩa': 823,
#  'chuôm': 824,
#  'dận': 825,
#  'gian': 826,
#  'trông': 827,
#  'kỹ_lưỡng': 828,
#  'khem_khổ': 829,
#  'mánh_khoé': 830,
#  'nhãi': 831,
#  'riêng_tư': 832,
#  'húng_chó': 833,
#  'vọt': 834,
#  'mung_lung': 835,
#  'nóng_nực': 836,
#  'ưa_chuộng': 837,
#  'sưng_vếu': 838,
#  'kền_kền': 839,
#  'khóm': 840,
#  'tỏ': 841,
#  'phản_đối': 842,
#  'bạc_đãi': 843,
#  'đương_nhiên': 844,
#  'đắc_chí': 845,
#  'huyết_tộc': 846,
#  'barie': 847,
#  'dị_hờm': 848,
#  'bít_tất': 849,
#  'thân_mật': 850,
#  'đầu_đanh': 851,
#  'phim_điện_ảnh': 852,
#  'thắt_cổ_bồng': 853,
#  'trọn_gói': 854,
#  'trêu': 855,
#  'thang_nhiệt_độ_Celsius': 856,
#  'mày_mặt': 857,
#  'nghỉ': 858,
#  'êm_đềm': 859,
#  'ghi_lòng_tạc_dạ': 860,
#  'nhời_nhẽ': 861,
#  'mặc_cả': 862,
#  'thiên_di': 863,
#  'không_những': 864,
#  'nội_quy': 865,
#  'bộ_nhớ_sơ_cấp': 866,
#  'cứa_cổ': 867,
#  'biến_đổi': 868,
#  'hoá_công': 869,
#  'thiệt_mạng': 870,
#  'chủ': 871,
#  'giũ': 872,
#  'có_bề_gì': 873,
#  'đăm_đắm': 874,
#  'đốn_kiếp': 875,
#  'lành_lặn': 876,
#  'độc_huyền': 877,
#  'vung_vẩy': 878,
#  'trở_quẻ': 879,
#  'huyễn_tưởng': 880,
#  'làm_chi': 881,
#  'nghề': 882,
#  'goá_phụ': 883,
#  'thư_kí': 884,
#  'tỷ_dụ': 885,
#  'lạ_thường': 886,
#  'cải_bắp': 887,
#  'chỉ_trích': 888,
#  'chào_mào': 889,
#  'hãi_kinh': 890,
#  'trở_lực': 891,
#  'mỹ_thuật': 892,
#  'dồn': 893,
#  'đi_tiểu': 894,
#  'ốc': 895,
#  'nức_nở': 896,
#  'xe_buýt': 897,
#  'ăn_lận': 898,
#  'nam_sài_hồ': 899,
#  'ngăn_nắp': 900,
#  'làng_xóm': 901,
#  'xanh_lướt': 902,
#  'mặc_nhiên': 903,
#  'gây_lộn': 904,
#  'mạt_cưa': 905,
#  'lấy_có': 906,
#  'CD-ROM': 907,
#  'ăn_ở': 908,
#  'láo_quáo': 909,
#  'toán_đố': 910,
#  'sớm_khuya': 911,
#  'lần_lữa': 912,
#  'lăng': 913,
#  'hôi_rình': 914,
#  're': 915,
#  'hét_lác': 916,
#  'di_dịch': 917,
#  'trực_tính': 918,
#  'tiên_tiến': 919,
#  'vẻn_vẹn': 920,
#  'uy_linh': 921,
#  'vô_kỳ_hạn': 922,
#  'đồn': 923,
#  'bồ_kếp': 924,
#  'bốp_chát': 925,
#  'mít_ráo': 926,
#  'đá_hoa_cương': 927,
#  'vòi_vĩnh': 928,
#  'một_lá_mầm': 929,
#  'đây_đẩy': 930,
#  'gã': 931,
#  'sai_lệch': 932,
#  'ninh': 933,
#  'dầu_phộng': 934,
#  'đầy': 935,
#  'khiếp': 936,
#  'mít_dai': 937,
#  'ngò': 938,
#  'nhún_nhường': 939,
#  'thêu_thùa': 940,
#  'táp_nham': 941,
#  'tái_tạo': 942,
#  'khiêu_vũ': 943,
#  'độ_trì': 944,
#  'giai_đoạn': 945,
#  'gác_thượng': 946,
#  'kều': 947,
#  'láng_máng': 948,
#  'thu_thanh': 949,
#  'ngấu_nghiến': 950,
#  'ký_tự': 951,
#  'lồi_lõm': 952,
#  'phối_chế': 953,
#  'im_thít': 954,
#  'tinh': 955,
#  'cây_xăng': 956,
#  'chân_thực': 957,
#  'qui_bản': 958,
#  'đanh_đá_cá_cày': 959,
#  'gian_giảo': 960,
#  'kéo_bè_kéo_cánh': 961,
#  'xe-non': 962,
#  'phơ_phới': 963,
#  'gặng': 964,
#  'linh_giác': 965,
#  'xoai_xoải': 966,
#  'tinh_khí': 967,
#  'lén': 968,
#  'đầu_trò': 969,
#  'ganh': 970,
#  'ầng_ậc': 971,
#  'tỷ_suất': 972,
#  'thấp_hèn': 973,
#  'oát': 974,
#  'tâm_sinh_lý': 975,
#  'loại_thể': 976,
#  'chết_giả': 977,
#  'cóc_khô': 978,
#  'tròn_bóng': 979,
#  'e': 980,
#  've_vuốt': 981,
#  'tân_trang': 982,
#  'cọc': 983,
#  'ruột_rà': 984,
#  'quên_khuấy': 985,
#  'tấu': 986,
#  'xích_đu': 987,
#  'đàm_phán': 988,
#  'đầu_máy': 989,
#  'hủi': 990,
#  'ngồi_không': 991,
#  'chế_độ_tư_bản': 992,
#  'hải_đăng': 993,
#  'nhất': 994,
#  'thông_gia': 995,
#  'tinh_giảm': 996,
#  'đồng_la': 997,
#  'dứa': 998,
#  'lổng_chổng': 999,
#  ...}

# %%
for pair in ant:
    pair = pair.split(' ')
    if len(pair) == 2: # contain 2 words
        w1, w2 = pair[0], pair[1]
        # one-hot encoding
        one_hot1 = np.zeros(len(corpus))
        one_hot1[corpus[w1]] = 1
        one_hot2 = np.zeros(len(corpus))
        one_hot2[corpus[w2]] = 1
        X.append([one_hot1, one_hot2])
        y.append(0)

# %%
for pair in syn:
    pair = pair.split(' ')
    if len(pair) == 2: # contain 2 words
        w1, w2 = pair[0], pair[1]
        one_hot1 = np.zeros(len(corpus))
        one_hot1[corpus[w1]] = 1
        one_hot2 = np.zeros(len(corpus))
        one_hot2[corpus[w2]] = 1
        X.append([one_hot1, one_hot2])
        y.append(1)

# %%
X = np.array(X)
y = np.array(y)
X = X.reshape(X.shape[0], -1)
print(X.shape, y.shape)
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=1)
# Out:
# (13562, 28300) (13562,)

# %%
epochs = 100

clf = MLPClassifier(hidden_layer_sizes=(256, 100, 100, 50), random_state=1, max_iter=epochs, verbose=True).fit(X_train, y_train)
pred = clf.predict(X_val)
score = f1_score(pred, y_val)
print("F1 for validate dataset is: ", score)
# Out:
# Iteration 1, loss = 0.43750922
# Iteration 2, loss = 0.17219359
# Iteration 3, loss = 0.04485404
# Iteration 4, loss = 0.02017860
# Iteration 5, loss = 0.01047814
# Iteration 6, loss = 0.00826773
# Iteration 7, loss = 0.00615374
# Iteration 8, loss = 0.00371194
# Iteration 9, loss = 0.00207706
# Iteration 10, loss = 0.00115505
# Iteration 11, loss = 0.00098236
# Iteration 12, loss = 0.00087462
# Iteration 13, loss = 0.00079998
# Iteration 14, loss = 0.00083895
# Iteration 15, loss = 0.00074640
# Iteration 16, loss = 0.00072955
# Iteration 17, loss = 0.00071223
# Iteration 18, loss = 0.00075186
# Iteration 19, loss = 0.00067084
# Iteration 20, loss = 0.00067832
# Iteration 21, loss = 0.00068254
# Iteration 22, loss = 0.00065496
# Iteration 23, loss = 0.00064031
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# F1 for validate dataset is:  0.9605234460196292

# %%
#TEST WITH ViCon-400 DATASET
nouns ='DATASET/ViCon-400/400_noun_pairs.txt'
verbs = 'DATASET/ViCon-400/400_verb_pairs.txt'
adjs = 'DATASET/ViCon-400/600_adj_pairs.txt'

nouns_split = pd.read_csv(nouns, sep=" ")
verbs_split = pd.read_csv(verbs, sep=" ")
adjs_split = pd.read_csv(adjs, sep=" ")

# %%
all_words = []
labels = []
X_test, y_test = [], []

#Concat three dataset to one
for i in nouns_split['Word1\tWord2\tRelation']: 
    w1, w2, label = i.split('\t')
    one_hot1 = np.zeros(len(corpus))
    if corpus.get(w1) is None:
        w1 = 'UNK'
    if corpus.get(w2) is None:
        w2 = 'UNK'
    one_hot1[corpus[w1]] = 1
    one_hot2 = np.zeros(len(corpus))
    one_hot2[corpus[w2]] = 1
    X_test.append([one_hot1, one_hot2])
    label = 1 if label=='SYN' else 0
    y_test.append(label)

for i in verbs_split['Word1\tWord2\tRelation']: 
    w1, w2, label = i.split('\t')
    one_hot1 = np.zeros(len(corpus))
    if corpus.get(w1) is None:
        w1 = 'UNK'
    if corpus.get(w2) is None:
        w2 = 'UNK'
    one_hot1[corpus[w1]] = 1
    one_hot2 = np.zeros(len(corpus))
    one_hot2[corpus[w2]] = 1
    X_test.append([one_hot1, one_hot2])
    label = 1 if label=='SYN' else 0
    y_test.append(label)
    
for i in adjs_split['Word1\tWord2\tRelation']: 
    w1, w2, label = i.split('\t')
    one_hot1 = np.zeros(len(corpus))
    if corpus.get(w1) is None:
        w1 = 'UNK'
    if corpus.get(w2) is None:
        w2 = 'UNK'
    one_hot1[corpus[w1]] = 1
    one_hot2 = np.zeros(len(corpus))
    one_hot2[corpus[w2]] = 1
    X_test.append([one_hot1, one_hot2])
    label = 1 if label=='SYN' else 0
    y_test.append(label)

# %%
X_test = np.array(X_test)
y_test = np.array(y_test)
X_test = X_test.reshape(X_test.shape[0], -1)
pred = clf.predict(X_test)
f1_score = f1_score(pred, y_test)
recall = recall_score(pred, y_test)
precision = precision_score(pred, y_test)

print("The F1-score of Vicon-400 dataset is: "+ str(f1_score*100) + "%")
print("Recall is:", recall)
print("Precision is: ", precision)
# Out:
# The F1-score of Vicon-400 dataset is: 97.65791341376863%
# Recall is: 0.9703808180535967
# Precision is:  0.9828571428571429

# %%
mis_cls = X_test[np.where(y_test+pred==1)]
mis_cls = np.reshape(mis_cls, (mis_cls.shape[0], 2, -1))

# %%
mis_cls.shape
# Out:
# (33, 2, 14150)
